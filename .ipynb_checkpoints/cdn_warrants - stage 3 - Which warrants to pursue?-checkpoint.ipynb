# %%
# Import modules
import pandas as pd

#from utils import *

from warrant_alert_generator import *

from warrant_aevaleva import *

# %%
# read in the filtered selection and display all warrants that satisfy the above filter
df = pd.DataFrame.from_csv('warrants_filtered_selection.csv', index_col=None, )

###==>  df

# %%
# calculate strenght of the alert signal - looking for at least 0.80

# DESCRIBE what it does
df['alert'] = df.apply(lambda row: gen_alert(row['leverage'], row['price-time-gain'], row['warrant']), axis=1)

# DESCRIBE what it does
df['avg_lvge'] = df.apply(lambda row: gen_avealeva(row['stock'], row['warrant'], row['exercise-price']), axis=1)

df
# Out:
#                      company    symbol   stock  exercise-price  warrant  \
# 0     Acasta Enterprises Inc    AEF.WT   8.750           11.50    1.200
# 1        Kew Media Group Inc    KEW.WT   9.850           11.50    1.670
# 2         Manitok Energy Inc    MEI.WT   0.115            0.18    0.025
# 3  Osisko Gold Royalties Ltd     OR.WT  14.260           36.50    2.400
# 4          Titan Medical Inc  TMD.WT.G   0.353            1.00    0.030
# 5          Titan Medical Inc  TMD.WT.H   0.353            1.20    0.035
# 6          Titan Medical Inc  TMD.WT.I   0.353            0.75    0.060
# 7  Trilogy Intl Partners Inc    TRL.WT   9.500           11.50    0.500
#
#    leverage expiry-date  price-time-gain alert avg_lvge
# 0       7.3  03/01/2022             0.02  0.88     4.18
# 1       5.9  13/06/2023             0.01  0.89     3.01
# 2       4.6  15/11/2021             0.03  0.98     2.36
# 3       5.9  18/02/2022             0.09  0.79     3.09
# 4      11.8  12/02/2021             0.14  0.93     6.32
# 5      10.1  31/03/2021             0.18  0.91     5.28
# 6       5.9  20/09/2021             0.07  0.95     3.11
# 7      19.0  07/02/2022             0.01  0.89    12.78

# %%
notnull_color = 'yellow'
df.style.applymap(lambda x: 'background-color: %s' % notnull_color if pd.notnull(x) else '')

#df.style.apply(lambda x: 'background-color: %s' % notnull_color if df.notnull(x) else '', subset=['alert'])
# Out:
#         <style  type="text/css" >
#
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col5 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col6 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col7 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow0_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col5 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col6 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col7 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow1_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col5 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col6 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col7 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow2_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col5 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col6 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col7 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow3_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col1 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col2 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col3 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col4 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col5 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col6 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col7 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col8 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow4_col9 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84ef18f42abdrow5_col0 {
#
#                 background-color:  yellow;
#
#             }
#
#             #T_14e8d7d8_5bf9_11e7_81df_84e

# %%
html = df.style.background_gradient(cmap='viridis', low=.8)
html
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/ithilien/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# /home/ithilien/anaconda3/lib/python3.6/site-packages/pandas/formats/style.py in _repr_html_(self)
#     190     def _repr_html_(self):
#     191         """Hooks into Jupyter notebook rich display system."""
# --> 192         return self.render()
#     193
#     194     def _translate(self):
#
# /home/ithilien/anaconda3/lib/python3.6/site-packages/pandas/formats/style.py in render(self)
#     415         the rendered HTML in the notebook.
#     416         """
# --> 417         self._compute()
#     418         d = self._translate()
#     419         # filter out empty styles, every cell will have a class
#
# /home/ithilien/anaconda3/lib/python3.6/site-packages/pandas/formats/style.py in _compute(self)
#     481         r = self
#     482         for func, args, kwargs in self._todo:
# --> 483             r = func(self)(*args, **kwargs)
#     484         return r
#     485
#
# /home/ithilien/anaconda3/lib/python3.6/site-packages/pandas/formats/style.py in _apply(self, func, axis, subset, **kwargs)
#     489         data = self.data.loc[subset]
#     490         if axis is not None:
# --> 491             result = data.apply(func, axis=axis, **kwargs)
#     492         else:
#     493             result = func(data, **kwargs)
#
# /home/ithilien/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /home/ithilien/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# /home/ithilien/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in f(x)
#    4127
#    4128             def f(x):
# -> 4129                 return func(x, *args, **kwds)
#    4130         else:
#    4131             f = func
#
# /home/ithilien/anaconda3/lib/python3.6/site-packages/pandas/formats/style.py in _background_gradient(s, cmap, low, high)
#     807         """Color background in a range according to the data."""
#     808         with _mpl(Styler.background_gradient) as (plt, colors):
# --> 809             rng = s.max() - s.min()
#     810             # extend lower / upper bounds, compresses color range
#     811             norm = colors.Normalize(s.min() - (rng * low),
#
# TypeError: ("unsupported operand type(s) for -: 'str' and 'str'", 'occurred at index alert')

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: #de4188' if v else '' for v in is_max]

df
# Out:
#                      company    symbol   stock  exercise-price  warrant  \
# 0     Acasta Enterprises Inc    AEF.WT   8.750           11.50    1.200
# 1        Kew Media Group Inc    KEW.WT   9.850           11.50    1.670
# 2         Manitok Energy Inc    MEI.WT   0.115            0.18    0.025
# 3  Osisko Gold Royalties Ltd     OR.WT  14.260           36.50    2.400
# 4          Titan Medical Inc  TMD.WT.G   0.353            1.00    0.030
# 5          Titan Medical Inc  TMD.WT.H   0.353            1.20    0.035
# 6          Titan Medical Inc  TMD.WT.I   0.353            0.75    0.060
# 7  Trilogy Intl Partners Inc    TRL.WT   9.500           11.50    0.500
#
#    leverage expiry-date  price-time-gain alert avg_lvge
# 0       7.3  03/01/2022             0.02  0.88     4.18
# 1       5.9  13/06/2023             0.01  0.89     3.01
# 2       4.6  15/11/2021             0.03  0.98     2.36
# 3       5.9  18/02/2022             0.09  0.79     3.09
# 4      11.8  12/02/2021             0.14  0.93     6.32
# 5      10.1  31/03/2021             0.18  0.91     5.28
# 6       5.9  20/09/2021             0.07  0.95     3.11
# 7      19.0  07/02/2022             0.01  0.89    12.78

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val >= 0.8 else 'black'
    return 'color: %s' % color

df.style.applymap(color_negative_red, subset=['alert', 'avg_lvge'])
df
# Out:
#                      company    symbol   stock  exercise-price  warrant  \
# 0     Acasta Enterprises Inc    AEF.WT   8.750           11.50    1.200
# 1        Kew Media Group Inc    KEW.WT   9.850           11.50    1.670
# 2         Manitok Energy Inc    MEI.WT   0.115            0.18    0.025
# 3  Osisko Gold Royalties Ltd     OR.WT  14.260           36.50    2.400
# 4          Titan Medical Inc  TMD.WT.G   0.353            1.00    0.030
# 5          Titan Medical Inc  TMD.WT.H   0.353            1.20    0.035
# 6          Titan Medical Inc  TMD.WT.I   0.353            0.75    0.060
# 7  Trilogy Intl Partners Inc    TRL.WT   9.500           11.50    0.500
#
#    leverage expiry-date  price-time-gain alert avg_lvge
# 0       7.3  03/01/2022             0.02  0.88     4.18
# 1       5.9  13/06/2023             0.01  0.89     3.01
# 2       4.6  15/11/2021             0.03  0.98     2.36
# 3       5.9  18/02/2022             0.09  0.79     3.09
# 4      11.8  12/02/2021             0.14  0.93     6.32
# 5      10.1  31/03/2021             0.18  0.91     5.28
# 6       5.9  20/09/2021             0.07  0.95     3.11
# 7      19.0  07/02/2022             0.01  0.89    12.78
